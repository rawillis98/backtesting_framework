# %%
from BH import BH
s = BH()
# Out:
# /home/alex/anaconda3/lib/python3.7/site-packages/pyfolio/pos.py:27: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; mutltipliers will not be applied' +
# [2020-01-07 22:26:36,723 - Buy and Hold - INFO]:	Initialized Buy and Hold!
# [2020-01-07 22:26:36,773 - Backend_Backtest - DEBUG]:	Order: SPYx740.0@135.0
# [2020-01-07 22:26:36,774 - matplotlib.pyplot - DEBUG]:	Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %%
s.run()
# Out:
# [2020-01-07 22:26:36,796 - Strategy - INFO]:	Running!
# [2020-01-07 22:26:36,799 - Strategy - DEBUG]:	Today is 2001-01-03
# [2020-01-07 22:26:36,801 - Strategy - INFO]:		Methods scheduled for 2001-01-03: []
# [2020-01-07 22:26:36,940 - numexpr.utils - INFO]:	NumExpr defaulting to 8 threads.
# [2020-01-07 22:26:36,942 - Strategy - INFO]:		Done for today! The next open is 2001-01-04 09:30:00
# [2020-01-07 22:26:36,942 - Backend_Backtest - INFO]:	Sleeping until f2001-01-04 09:30:00
# [2020-01-07 22:26:36,943 - Backend_Backtest - INFO]:	Done sleeping
# [2020-01-07 22:26:36,943 - Strategy - DEBUG]:	Today is 2001-01-04
# [2020-01-07 22:26:36,944 - Strategy - INFO]:		Methods scheduled for 2001-01-04: []
# [2020-01-07 22:26:37,044 - Strategy - INFO]:		Done for today! The next open is 2001-01-05 09:30:00
# [2020-01-07 22:26:37,044 - Backend_Backtest - INFO]:	Sleeping until f2001-01-05 09:30:00
# [2020-01-07 22:26:37,045 - Backend_Backtest - INFO]:	Done sleeping
# ...

# %%
s.analyze()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2001-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-06-03</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>220</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>3.9%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>103.3%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>18.8%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.30</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.07</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.71</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-56.4%</td>
#     </tr>
#     <tr>
# ...
